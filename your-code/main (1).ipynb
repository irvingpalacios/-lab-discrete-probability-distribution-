# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %%
import matplotlib.pyplot as plt
import numpy as np


from scipy.stats import bernoulli, binom, poisson

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
"""
Calculate:
p = probability that the fruit is an apple 
q = probability that the fruit is an orange
"""

# your code here

p=(60/100)
q=40/100
print('p=',p)
print('q=',q)
# Out:
# p= 0.6
# q= 0.4

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 1. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
# your code here

print("What is the probability that the first 5 fruits are all apples?\n")

print(p**5)

print("\nWhat is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?\n")

(p**5)*(q**15)
# Out:
# What is the probability that the first 5 fruits are all apples?
#
# 0.07775999999999998
#
# What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?
# 8.349416423424006e-08

# %%
# your code here

##What is the probability that the first 5 fruits are all apples?

apples_ber=bernoulli.pmf(1,p)
oranges_ber=bernoulli.pmf(0,p)
print("Probability that the first 5 fruitss are apples:",apples_ber,"\n\n")
##What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?

print("Probability that the first 5 fruits are all apples and the next 15 fruits are all oranges:\n",(apples_ber**5)*(oranges_ber**15))
# Out:
# Probability that the first 5 fruitss are apples: 0.6
#
#
# Probability that the first 5 fruits are all apples and the next 15 fruits are all oranges:
#  8.349416423424006e-08

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %% [markdown]
# [texto del vínculo](https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-479b891bc07c38b746bccaec1c5bac6f_l3.svg)

# %%
# your code here
apples_bin=binom.pmf(5, 20, p)
oranges_bin=binom.pmf(15, 20, q)

print(apples_bin)
print(oranges_bin)


#Here we can appreciate that no matter how we analize the problem (from oranges or apples)
#We will get the same value because the probabilities of failure or success change too.
# Out:
# 0.0012944935222876511
# 0.0012944935222876511

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
# your code here

n=20

binomial= binom(n,p)

print(binomial.cdf(4))
# Out:
# 0.0003170311211686301

# %% [markdown]
# **Plot the PDF (probability distributiom function) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
# your code here

n=20
p=0.6

x = np.arange(0,n)
fig, ax = plt.subplots(1, 1)
ax.plot(x, binom.pmf(x, n, p), 'bo')
ax.vlines(x, 0, binom.pmf(x, n, p), colors='g', lw=5, alpha=0.2)

# Please label the axes and give a title to the plot 


plt.xlabel('Number of apples')
plt.ylabel('Probability')
plt.title('PDF Binomial Distribution (Apples)')
# Out:
# Text(0.5, 1.0, 'PDF Binomial Distribution (Apples)')

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# *Hint: Use the exp() in the math library*
#
# And to calculate the factorial, you can use the following code:
#
# ```python
# import math
# math.factorial(n) # n is the number you want to find the factorial of
# ```

# %%
import math

med=2.3

k=math.factorial(5)
exp= math.exp(-med)

# %%
# your code here 
f=exp*((2.3**5)/(k))
f
# Out:
# 0.05377502558194681

# %%
g=poisson.pmf(5,med)
g
# Out:
# 0.053775025581946814

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
# your code here
# Please label the axes and give a title to the plot 

n=med
k=5

x =np.arange(0,11)
fig, ax = plt.subplots(1, 1)
ax.plot(x, poisson.pmf(x, n), 'bo')
ax.vlines(x, 0, poisson.pmf(x, n), colors='g', lw=5, alpha=0.2)

# Please label the axes and give a title to the plot 


plt.xlabel('Number of goals')
plt.ylabel('Probability')
plt.title('Poisson probability distribution for the # of goals between 0-10')
# Out:
# Text(0.5, 1.0, 'Poisson probability distribution for the # of goals between 0-10')
